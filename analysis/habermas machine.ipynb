# %%
import io
import requests
import pandas as pd

file_location = (
    'https://storage.googleapis.com/habermas_machine/datasets/hm_all_round_survey_responses.parquet'
)
response = requests.get(file_location)
with io.BytesIO(response.content) as f:
    df = pd.read_parquet(f)

# %%
df
# Out:
#        index  monotonic_timestamp  best_expression  \
# 0          0     1679993502647784  FINAL_CONSENSUS
# 1          1     1679993502649799      OWN_OPINION
# 2          2     1679993502651380  FINAL_CONSENSUS
# 3          3     1679993502679049  FINAL_CONSENSUS
# 4          4     1679993502680866  FINAL_CONSENSUS
# ...      ...                  ...              ...
# 21603     85     1684581125729772             MOCK
# 21604     86     1684581125762807  FINAL_CONSENSUS
# 21605     87     1684581125766939  FINAL_CONSENSUS
# 21606     88     1684581125770626      OWN_OPINION
# 21607     89     1684581125775878      OWN_OPINION
#
#       candidate.aggregation.method  \
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ...                            ...
# 21603                      SCHULZE
# 21604                      SCHULZE
# 21605                      SCHULZE
# 21606                      SCHULZE
# 21607                      SCHULZE
#
#                         candidate.all_reward_predictions  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 21603  [[0.014356954954564571, 2.070845603942871, 0.9...
# 21604  [[0.014356954954564571, 2.070845603942871, 0.9...
# 21605  [[0.014356954954564571, 2.070845603942871, 0.9...
# 21606  [[0.014356954954564571, 2.070845603942871, 0.9...
# 21607  [[0.014356954954564571, 2.070845603942871, 0.9...
#
#                                      candidate.all_texts  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 21603  [“NO, we should not raise the retirement age f...
# 21604  [“NO, we should not raise the retirement age f...
# 21605  [“NO, we should not raise the retirement age f...
# 21606  [“NO, we should not raise the retirement age f...
# 21607  [“NO, we should not raise the retirement age f...
#
#       candidate.display_label        candidate.metadata.created  \
# 0                           c  2023-03-28T08:14:19.472449+00:00
# 1                           c  2023-03-28T08:14:19.472449+00:00
# 2                           c  2023-03-28T08:14:19.472449+00:00
# 3                           c  2023-03-28T08:14:19.472449+00:00
# 4                           c  2023-03-28T08:14:19.472449+00:00
# ...                       ...                               ...
# 21603                       c  2023-05-20T00:37:14.581936+00:00
# 21604                       c  2023-05-20T00:37:14.581936+00:00
# 21605                       c  2023-05-20T00:37:14.581936+00:00
# 21606                       c  2023-05-20T00:37:14.581936+00:00
# 21607                       c  2023-05-20T00:37:14.581936+00:00
#
#       candidate.metadata.generative_model.api_version  \
# 0                                          chinchilla
# 1                                          chinchilla
# 2                                          chinchilla
# 3                                          chinchilla
# 4                                          chinchilla
# ...                                               ...
# 21603                            hydra_70b_generative
# 21604                            hydra_70b_generative
# 21605                            hydra_70b_generative
# 21606                            hydra_70b_generative
# 21607                            hydra_70b_generative
#
#       candidate.metadata.generative_model.template_name  ... question.topic  \
# 0                                          CITIZEN_JURY  ...             66
# 1                                          CITIZEN_JURY  ...             66
# 2                                          CITIZEN_JURY  ...             66
# 3                                          CITIZEN_JURY  ...             66
# 4                                          CITIZEN_JURY  ...             66
# ...                                                 ...  ...            ...
# 21603                                 PARTICIPANT_GROUP  ...             50
# 21604                                 PARTICIPANT_GROUP  ...             50
# 21605                                 PARTICIPANT_GROUP  ...             50
# 21606                                 PARTICIPANT_GROUP  ...             50
# 21607                                 PARTICIPANT_GROUP  ...             50
#
#       survey_likert_no_to_yes                  timestamp unwanted_pressure  \
# 0                       False 2023-03-28 08:51:42.647779                NO
# 1                       False 2023-03-28 08:51:42.649798                NO
# 2                       False 2023-03-28 08:51:42.651380                NO
# 3                        True 2023-03-28 08:51:42.679047                NO
# 4                        True 2023-03-28 08:51:42.680865                NO
# ...                       ...                        ...               ...
# 21603                   False 2023-05-20 11:12:05.729769              MOCK
# 21604                    True 2023-05-20 11:12:05.762805                NO
# 21605                    True 2023-05-20 11:12:05.766936                NO
# 21606                   False 2023-05-20 11:12:05.770624                NO
# 21607                   False 2023-05-20 11:12:05.775875                NO
#
#       view_change        view_movement  \
# 0              NO            NO_CHANGE
# 1              NO            NO_CHANGE
# 2              NO  CLOSER_TO_CONSENSUS
# 3              NO            NO_CHANGE
# 4              NO            NO_CHANGE
# ...           ...                  ...
# 21603        MOCK                 MOCK
# 21604         YES  CLOSER_TO_CONSENSUS
# 21605         YES  CLOSER_TO_CONSENSUS
# 21606          NO            NO_CHANGE
# 21607          NO            NO_CHANGE
#
#                            candidate.all_welfare_or_rank  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 21603  [0, 1, 2, 3, 3, 4, 4, 5, 5, 6, 6, 6, 6, 7, 7, ...
# 21604  [0, 1, 2, 3, 3, 4, 4, 5, 5, 6, 6, 6, 6, 7, 7, ...
# 21605  [0, 1, 2, 3, 3, 4, 4, 5, 5, 6, 6, 6, 6, 7, 7, ...
# 21606  [0, 1, 2, 3, 3, 4, 4, 5, 5, 6, 6, 6, 6, 7, 7, ...
# 21607  [0, 1, 2, 3, 3, 4, 4, 5, 5, 6, 6, 6, 6, 7, 7, ...
#
#       candidate.reward_data.welfare_or_rank  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 21603                                   0.0
# 21604                                   0.0
# 21605                                   0.0
# 21606                                   0.0
# 21607                                   0.0
#
#                                         view_explanation worker_id
# 0                                                   None      None
# 1                                                   None      None
# 2                                                   None      None
# 3                                                   None      None
# 4                                                   None      None
# ...                                                  ...       ...
# 21603                                  Mock explanation.  5f14831c
# 21604  my view changed slightly as i agree the age sh...  72174320
# 21605               The group opinion is more inclusive.  5373b96e
# 21606             No new information was given by others  df62ef98
# 21607  The group opinion is contradictory and factual...  431baa7a
#
# [21608 rows x 51 columns]
